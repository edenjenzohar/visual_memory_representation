# %%
import numpy as np
import pandas as pd 
from pathlib import Path
from pulp import *
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time 
import scipy.stats as stats

from io import BytesIO #apparanetly needed for reading the files from the bucket
from google.cloud import storage

# %%
storage_client = storage.Client()
# Define the bucket name and file name
bucket_name = 'memory_represetnations_data'
file_name = 'images_info_multicat.csv' #you can also try to load something that is not within a subfolder: i.e: 'Object and scene categories in brain and behavior/set1.csv'

# Get the bucket and blob objects
bucket = storage_client.get_bucket(bucket_name)

def read_csv_from_bucket(bucket,filename):
    blob = bucket.blob(filename)

    # Read the content of the file into a BytesIO object
    content = blob.download_as_string()
    content = BytesIO(content)

    # Load the content into a pandas DataFrame using pd.read_csv
    df = pd.read_csv(content)
    return df

def save_df_csv_into_bucket(bucket,df,filename):
    output_blob = bucket.blob(filename)
    output_blob.upload_from_string(df.to_csv(index=False), content_type='text/csv')

# %%
#here is how to read it: 
test_df=read_csv_from_bucket(bucket=bucket,filename=file_name)
#here is how to save with a new name: 
test_filename='dekels_bucket_save_test.csv'
save_df_csv_into_bucket(bucket,df,test_filename)

# %%
#example on how to list all bucket contents
blobs = bucket.list_blobs()
# Print the names of all the blobs
for blob in blobs:

    print(blob.name)
# Out:
# .ipynb_checkpoints/
# Object and scene categories in brain and behavior/set1.csv
# Object and scene categories in brain and behavior/set1/0001.jpg
# Object and scene categories in brain and behavior/set1/0002.jpg
# Object and scene categories in brain and behavior/set1/0003.jpg
# Object and scene categories in brain and behavior/set1/0004.jpg
# Object and scene categories in brain and behavior/set1/0005.jpg
# Object and scene categories in brain and behavior/set1/0006.jpg
# Object and scene categories in brain and behavior/set1/0007.jpg
# Object and scene categories in brain and behavior/set1/0008.jpg
# Object and scene categories in brain and behavior/set1/0009.jpg
# Object and scene categories in brain and behavior/set1/0010.jpg
# Object and scene categories in brain and behavior/set1/0011.jpg
# Object and scene categories in brain and behavior/set1/0012.jpg
# Object and scene categories in brain and behavior/set1/0013.jpg
# Object and scene categories in brain and behavior/set1/0014.jpg
# Object and scene categories in brain and behavior/set1/0015.jpg
# Object and scene categories in brain and behavior/set1/0016.jpg
# Object and scene categories in brain and behavior/set1/0017.jpg
# Object and scene categories in brain and behavior/set1/0018.jpg
# Object and scene categories in brain and behavior/set1/0019.jpg
# Object and scene categories in brain and behavior/set1/0020.jpg
# Object and scene categories in brain and behavior/set1/0021.jpg
# Object and scene categories in brain and behavior/set1/0022.jpg
# Object and scene categories in brain and behavior/set1/0023.jpg
# Object and scene categories in brain and behavior/set1/0024.jpg
# Object and scene categories in brain and behavior/set1/0025.jpg
# Object and scene categories in brain and behavior/set1/0026.jpg
# Object and scene categories in brain and behavior/set1/0027.jpg
# Object and scene categories in brain and behavior/set1/0028.jpg
# Object and scene categories in brain and behavior/set1/0029.jpg
# Object and scene categories in brain and behavior/set1/0030.jpg
# Object and scene categories in brain and behavior/set1/0031.jpg
# Object and scene categories in brain and behavior/set1/0032.jpg
# Object and scene categories in brain and behavior/set1/0033.jpg
# Object and scene categories in brain and behavior/set1/0034.jpg
# Object and scene categories in brain and behavior/set1/0035.jpg
# Object and scene categories in brain and behavior/set1/0036.jpg
# Object and scene categories in brain and behavior/set1/0037.jpg
# Object and scene categories in brain and behavior/set1/0038.jpg
# Object and scene categories in brain and behavior/set1/0039.jpg
# Object and scene categories in brain and behavior/set1/0040.jpg
# Object and scene categories in brain and behavior/set1/0041.jpg
# Object and scene categories in brain and behavior/set1/0042.jpg
# Object and scene categories in brain and behavior/set1/0043.jpg
# Object and scene categories in brain and behavior/set1/0044.jpg
# Object and scene categories in brain and behavior/set1/0045.jpg
# Object and scene categories in brain and behavior/set1/0046.jpg
# Object and scene categories in brain and behavior/set1/0047.jpg
# Object and scene categories in brain and behavior/set1/0048.jpg
# Object and scene categories in brain and behavior/set1/0049.jpg
# Object and scene categories in brain and behavior/set1/0050.jpg
# Object and scene categories in brain and behavior/set1/0051.jpg
# Object and scene categories in brain and behavior/set1/0052.jpg
# Object and scene categories in brain and behavior/set1/0053.jpg
# Object and scene categories in brain and behavior/set1/0054.jpg
# Object and scene categories in brain and behavior/set1/0055.jpg
# Object and scene categories in brain and behavior/set1/0056.jpg
# Object and scene categories in brain and behavior/set1/0057.jpg
# Object and scene categories in brain and behavior/set1/0058.jpg
# Object and scene categories in brain and behavior/set1/0059.jpg
# Object and scene categories in brain and behavior/set1/0060.jpg
# Object and scene categories in brain and behavior/set1/0061.jpg
# Object and scene categories in brain and behavior/set1/0062.jpg
# Object and scene categories in brain and behavior/set1/0063.jpg
# Object and scene categories in brain and behavior/set1/0064.jpg
# Object and scene categories in brain and behavior/set1/0065.jpg
# Object and scene categories in brain and behavior/set1/0066.jpg
# Object and scene categories in brain and behavior/set1/0067.jpg
# Object and scene categories in brain and behavior/set1/0068.jpg
# Object and scene categories in brain and behavior/set1/0069.jpg
# Object and scene categories in brain and behavior/set1/0070.jpg
# Object and scene categories in brain and behavior/set1/0071.jpg
# Object and scene categories in brain and behavior/set1/0072.jpg
# Object and scene categories in brain and behavior/set1/0073.jpg
# Object and scene categories in brain and behavior/set1/0074.jpg
# Object and scene categories in brain and behavior/set1/0075.jpg
# Object and scene categories in brain and behavior/set1/0076.jpg
# Object and scene categories in brain and behavior/set1/0077.jpg
# Object and scene categories in brain and behavior/set1/0078.jpg
# Object and scene categories in brain and behavior/set1/0079.jpg
# Object and scene categories in brain and behavior/set1/0080.jpg
# Object and scene categories in brain and behavior/set1/0081.jpg
# Object and scene categories in brain and behavior/set1/0082.jpg
# Object and scene categories in brain and behavior/set1/0083.jpg
# Object and scene categories in brain and behavior/set1/0084.jpg
# Object and scene categories in brain and behavior/set1/0085.jpg
# Object and scene categories in brain and behavior/set1/0086.jpg
# Object and scene categories in brain and behavior/set1/0087.jpg
# Object and scene categories in brain and behavior/set1/0088.jpg
# Object and scene categories in brain and behavior/set1/0089.jpg
# Object and scene categories in brain and behavior/set1/0090.jpg
# Object and scene categories in brain and behavior/set1/0091.jpg
# Object and scene categories in brain and behavior/set1/0092.jpg
# Object and scene categories in brain and behavior/set1/0093.jpg
# Object and scene categories in brain and behavior/set1/0094.jpg
# Object and scene categories in brain and behavior/set1/0095.jpg
# Object and scene categories in brain and behavior/set1/0096.jpg
# Object and scene categories in brain and behavior/set1/0097.jpg
# Object and scene categories in brain and behavior/set1/0098.jpg
# Object and scene categories in brain and behavior/set1/0099.jpg
# Object and scene categories in brain and behavior/set1/0100.jpg
# Object and scene categories in brain and behavior/set1/0101.jpg
# Object and scene categories in brain and behavior/set1/0102.jpg
# Object and scene categories in brain and behavior/set1/0103.jpg
# Object and scene categories in brain and behavior/set1/0104.jpg
# Object and scene categories in brain and behavior/set1/0105.jpg
# Object and scene categories in brain and behavior/set1/0106.jpg
# Object and scene categories in brain and behavior/set1/0107.jpg
# Object and scene categories in brain and behavior/set1/0108.jpg
# Object and scene categories in brain and behavior/set1/0109.jpg
# Object and scene categories in brain and behavior/set1/0110.jpg
# Object and scene categories in brain and behavior/set1/0111.jpg
# Object and scene categories in brain and behavior/set1/0112.jpg
# Object and scene categories in brain and behavior/set1/0113.jpg
# Object and scene categories in brain and behavior/set1/0114.jpg
# Object and scene categories in brain and behavior/set1/0115.jpg
# Object and scene categories in brain and behavior/set1/0116.jpg
# Object and scene categories in brain and behavior/set1/0117.jpg
# Object and scene categories in brain and behavior/set1/0118.jpg
# Object and scene categories in brain and behavior/set1/0119.jpg
# Object and scene categories in brain and behavior/set1/0120.jpg
# Object and scene categories in brain and behavior/set1/0121.jpg
# Object and scene categories in brain and behavior/set1/0122.jpg
# Object and scene categories in brain and behavior/set1/0123.jpg
# Object and scene categories in brain and behavior/set1/0124.jpg
# Object and scene categories in brain and behavior/set1/0125.jpg
# Object and scene categories in brain and behavior/set1/0126.jpg
# Object and scene categories in brain and behavior/set1/0127.jpg
# Object and scene categories in brain and behavior/set1/0128.jpg
# Object and scene categories in brain and behavior/set1/0129.jpg
# Object and scene categories in brain and behavior/set1/0130.jpg
# Object and scene categories in brain and behavior/set1/0131.jpg
# Object and scene categories in brain and behavior/set1/0132.jpg
# Object and scene categories in brain and behavior/set1/0133.jpg
# Object and scene categories in brain and behavior/set1/0134.jpg
# Object and scene categories in brain and behavior/set1/0135.jpg
# Object and scene categories in brain and behavior/set1/0136.jpg
# Object and scene categories in brain and behavior/set1/0137.jpg
# Object and scene categories in brain and behavior/set1/0138.jpg
# Object and scene categories in brain and behavior/set1/0139.jpg
# Object and scene categories in brain and behavior/set1/0140.jpg
# Object and scene categories in brain and behavior/set1/0141.jpg
# Object and scene categories in brain and behavior/set1/0142.jpg
# Object and scene categories in brain and behavior/set1/0143.jpg
# Object and scene categories in brain and behavior/set1/0144.jpg
# Object and scene categories in brain and behavior/set2.csv
# Object and scene categories in brain and behavior/set2/0001.jpg
# Object and scene categories in brain and behavior/set2/0002.jpg
# Object and scene categories in brain and behavior/set2/0003.jpg
# Object and scene categories in brain and behavior/set2/0004.jpg
# Object and scene categories in brain and behavior/set2/0005.jpg
# Object and scene categories in brain and behavior/set2/0006.jpg
# Object and scene categories in brain and behavior/set2/0007.jpg
# Object and scene categories in brain and behavior/set2/0008.jpg
# Object and scene categories in brain and behavior/set2/0009.jpg
# Object and scene categories in brain and behavior/set2/0010.jpg
# Object and scene categories in brain and behavior/set2/0011.jpg
# Object and scene categories in brain and behavior/set2/0012.jpg
# Object and scene categories in brain and behavior/set2/0013.jpg
# Object and scene categories in brain and behavior/set2/0014.jpg
# Object and scene categories in brain and behavior/set2/0015.jpg
# Object and scene categories in brain and behavior/set2/0016.jpg
# Object and scene categories in brain and behavior/set2/0017.jpg
# Object and scene categories in brain and behavior/set2/0018.jpg
# Object and scene categories in brain and behavior/set2/0019.jpg
# Object and scene categories in brain and behavior/set2/0020.jpg
# Object and scene categories in brain and behavior/set2/0021.jpg
# Object and scene categories in brain and behavior/set2/0022.jpg
# Object and scene categories in brain and behavior/set2/0023.jpg
# Object and scene categories in brain and behavior/set2/0024.jpg
# Object and scene categories in brain and behavior/set2/0025.jpg
# Object and scene categories in brain and behavior/set2/0026.jpg
# Object and scene categories in brain and behavior/set2/0027.jpg
# Object and scene categories in brain and behavior/set2/0028.jpg
# Object and scene categories in brain and behavior/set2/0029.jpg
# Object and scene categories in brain and behavior/set2/0030.jpg
# Object and scene categories in brain and behavior/set2/0031.jpg
# Object and scene categories in brain and behavior/set2/0032.jpg
# Object and scene categories in brain and behavior/set2/0033.jpg
# Object and scene categories in brain and behavior/set2/0034.jpg
# Object and scene categories in brain and behavior/set2/0035.jpg
# Object and scene categories in brain and behavior/set2/0036.jpg
# Object and scene categories in brain and behavior/set2/0037.jpg
# Object and scene categories in brain and behavior/set2/0038.jpg
# Object and scene categories in brain and behavior/set2/0039.jpg
# Object and scene categories in brain and behavior/set2/0040.jpg
# Object and scene categories in brain and behavior/set2/0041.jpg
# Object and scene categories in brain and behavior/set2/0042.jpg
# Object and scene categories in brain and behavior/set2/0043.jpg
# Object and scene categories in brain and behavior/set2/0044.jpg
# Object and scene categories in brain and behavior/set2/0045.jpg
# Object and scene categories in brain and behavior/set2/0046.jpg
# Object and scene categories in brain and behavior/set2/0047.jpg
# Object and scene categories in brain and behavior/set2/0048.jpg
# Object and scene categories in brain and behavior/set2/0049.jpg
# Object and scene categories in brain and behavior/set2/0050.jpg
# Object and scene categories in brain and behavior/set2/0051.jpg
# Object and scene categories in brain and behavior/set2/0052.jpg
# Object and scene categories in brain and behavior/set2/0053.jpg
# Object and scene categories in brain and behavior/set2/0054.jpg
# Object and scene categories in brain and behavior/set2/0055.jpg
# Object and scene categories in brain and behavior/set2/0056.jpg
# Object and scene categories in brain and behavior/set2/0057.jpg
# Object and scene categories in brain and behavior/set2/0058.jpg
# Object and scene categories in brain and behavior/set2/0059.jpg
# Object and scene categories in brain and behavior/set2/0060.jpg
# Object and scene categories in brain and behavior/set2/0061.jpg
# Object and scene categories in brain and behavior/set2/0062.jpg
# Object and scene categories in brain and behavior/set2/0063.jpg
# Object and scene categories in brain and behavior/set2/0064.jpg
# Object and scene categories in brain and behavior/set2/0065.jpg
# Object and scene categories in brain and behavior/set2/0066.jpg
# Object and scene categories in brain and behavior/set2/0067.jpg
# Object and scene categories in brain and behavior/set2/0068.jpg
# Object and scene categories in brain and behavior/set2/0069.jpg
# Object and scene categories in brain and behavior/set2/0070.jpg
# Object and scene categories in brain and behavior/set2/0071.jpg
# Object and scene categories in brain and behavior/set2/0072.jpg
# Object and scene categories in brain and behavior/set2/0073.jpg
# Object and scene categories in brain and behavior/set2/0074.jpg
# Object and scene categories in brain and behavior/set2/0075.jpg
# Object and scene categories in brain and behavior/set2/0076.jpg
# Object and scene categories in brain and behavior/set2/0077.jpg
# Object and scene categories in brain and behavior/set2/0078.jpg
# Object and scene categories in brain and behavior/set2/0079.jpg
# Object and scene categories in brain and behavior/set2/0080.jpg
# Object and scene categories in brain and behavior/set2/0081.jpg
# Object and scene categories in brain and behavior/set2/0082.jpg
# Object and scene categories in brain and behavior/set2/0083.jpg
# Object and scene categories in brain and behavior/set2/0084.jpg
# Object and scene categories in brain and behavior/set2/0085.jpg
# Object and scene categories in brain and behavior/set2/0086.jpg
# Object and scene categories in brain and behavior/set2/0087.jpg
# Object and scene categories in brain and behavior/set2/0088.jpg
# Object and scene categories in brain and behavior/set2/0089.jpg
# Object and scene categories in brain and behavior/set2/0090.jpg
# Object and scene categories in brain and behavior/set2/0091.jpg
# Object and scene categories in brain and behavior/set2/0092.jpg
# Object and scene categories in brain and behavior/set2/0093.jpg
# Object and scene categories in brain and behavior/set2/0094.jpg
# Object and scene categories in brain and behavior/set2/0095.jpg
# Object and scene categories in brain and behavior/set2/0096.jpg
# Object and scene categories in brain and behavior/set2/0097.jpg
# Object and scene categories in brain and behavior/set2/0098.jpg
# Object and scene categories in brain and behavior/set2/0099.jpg
# Object and scene categories in brain and behavior/set2/0100.jpg
# Object and scene categories in brain and behavior/set2/0101.jpg
# Object and scene categories in brain and behavior/set2/0102.jpg
# Object and scene categories in brain and behavior/set2/0103.jpg
# Object and scene categories in brain and behavior/set2/0104.jpg
# Object and scene categories in brain and behavior/set2/0105.jpg
# Object and scene categories in brain and behavior/set2/0106.jpg
# Object and scene categories in brain and behavior/set2/0107.jpg
# Object and scene categories in brain and behavior/set2/0108.jpg
# Object and scene categories in brain and behavior/set2/0109.jpg
# Object and scene categories in brain and behavior/set2/0110.jpg
# Object and scene categories in brain and behavior/set2/0111.jpg
# Object and scene categories in brain and behavior/set2/0112.jpg
# Object and scene categories in brain and behavior/set2/0113.jpg
# Object and scene categories in brain and behavior/set2/0114.jpg
# Object and scene categories in brain and behavior/set2/0115.jpg
# Object and scene categories in brain and behavior/set2/0116.jpg
# Object and scene categories in brain and behavior/set2/0117.jpg
# Object and scene categories in brain and behavior/set2/0118.jpg
# Object and scene categories in brain and behavior/set2/0119.jpg
# Object and scene categories in brain and behavior/set2/0120.jpg
# Object and scene categories in brain and behavior/set2/0121.jpg
# Object and scene categories in brain and behavior/set2/0122.jpg
# Object and scene categories in brain and behavior/set2/0123.jpg
# Object and scene categories in brain and behavior/set2/0124.jpg
# Object and scene categories in brain and behavior/set2/0125.jpg
# Object and scene categories in brain and behavior/set2/0126.jpg
# Object and scene categories in brain and behavior/set2/0127.jpg
# Object and scene categories in brain and behavior/set2/0128.jpg
# Object and scene categories in brain and behavior/set2/0129.jpg
# Object and scene categories in brain and behavior/set2/0130.jpg
# Object and scene categories in brain and behavior/set2/0131.jpg
# Object and scene categories in brain and behavior/set2/0132.jpg
# Object and scene categories in brain and behavior/set2/0133.jpg
# Object and scene categories in brain and behavior/set2/0134.jpg
# Object and scene categories in brain and behavior/set2/0135.jpg
# Object and scene categories in brain and behavior/set2/0136.jpg
# Object and scene categories in brain and behavior/set2/0137.jpg
# Object and scene categories in brain and behavior/set2/0138.jpg
# Object and scene categories in brain and behavior/set2/0139.jpg
# Object and scene categories in brain and behavior/set2/0140.jpg
# Object and scene categories in brain and behavior/set2/0141.jpg
# Object and scene categories in brain and behavior/set2/0142.jpg
# Object and scene categories in brain and behavior/set2/0143.jpg
# Object and scene categories in brain and behavior/set2/0144.jpg
# Object and scene categories in brain and behavior/stimulus_category_labels.txt
# badlands_epsilon_0.05.csv
# badlands_epsilon_0.1.csv
# behavioral/
# behavioral/correlation to behavioral data.jpg
# behavioral/similarity_VGG_1.csv
# behavioral/similarity_VGG_1_5.csv
# behavioral/similarity_VGG_2.csv
# behavioral/similarity_VGG_2_5.csv
# behavioral/similarity_VGG_index_1.csv
# behavioral/similarity_VGG_index_1_5.csv
# behavioral/similarity_VGG_index_2.csv
# behavioral/similarity_VGG_index_2_5.csv
# behavioral/similarity_VGG_regular_indexbehavioral.csv
# behavioral/similarity_VGG_regularbehavioral.csv
# behavioral/similarity_topx_VGG_1.csv
# behavioral/similarity_topx_VGG_1_5.csv
# behavioral/similarity_topx_VGG_2.csv
# behavioral/similarity_topx_VGG_index_1.csv
# behavioral/similarity_topx_VGG_index_1_5.csv
# behavioral/similarity_topx_VGG_index_2.csv
# behavioral/similarity_topx_per_cat_1.csv
# behavioral/similarity_topx_per_cat_1_5.csv
# behavioral/similarity_topx_per_cat_2.csv
# behavioral/similarity_topx_per_cat_index_1.csv
# behavioral/similarity_topx_per_cat_index_1_5.csv
# behavioral/similarity_topx_per_cat_index_2.csv
# behavioral/similarity_topx_per_cat_percentile_VGG_85.csv
# behavioral/similarity_topx_per_cat_percentile_VGG_90.csv
# behavioral/similarity_topx_per_cat_percentile_VGG_95.csv
# behavioral/similarity_topx_per_cat_percentile_VGG_index_85.csv
# behavioral/similarity_topx_per_cat_percentile_VGG_index_90.csv
# behavioral/similarity_topx_per_cat_percentile_VGG_index_95.csv
# behavioral/sum_activations.pt
# bridge_epsilon_0.05.csv
# bridge_epsilon_0.1.csv
# dekels_bucket_save_test.csv
# golf_course_epsilon_0.05.csv
# golfcourse_epsilon_0.1.csv
# highway_epsilon_0.05.csv
# highway_epsilon_0.1.csv
# images_info_behavioral.csv
# images_info_multicat.csv
# images_info_multicategory.csv
# images_info_validation check.csv
# informative_nodes.pickle
# mountain_epsilon_0.05.csv
# mountain_epsilon_0.1.csv
# multicategory/
# multicategory/.ipynb_checkpoints/
# multicategory/plan_a_std_1.jpg
# multicategory/plan_a_std_2.jpg
# multicategory/regular.jpg
# multicategory/silluoettes_results.csv
# multicategory/similarity_VGG_index_multicategory_1.csv
# multicategory/similarity_VGG_index_multicategory_2.csv
# multicategory/similarity_VGG_multicategory_1.csv
# multicategory/similarity_VGG_multicategory_2.csv
# multicategory/similarity_VGG_regular_indexmulticategory.csv
# multicategory/similarity_VGG_regularmulticategory.csv
# multicategory/similarity_topx_per_cat_1.csv
# multicategory/similarity_topx_per_cat_1_5.csv
# multicategory/similarity_topx_per_cat_2.csv
# multicategory/similarity_topx_per_cat_index_1.csv
# multicategory/similarity_topx_per_cat_index_1_5.csv
# multicategory/similarity_topx_per_cat_index_2.csv
# multicategory/sum_activations.pt
# multicategory/topx_std_1.jpg
# multicategory/topx_std_1_5.jpg
# multicategory/topx_std_2.jpg
# neurons_idx_used_for_similarity_VGG_badlands_1.csv
# neurons_idx_used_for_similarity_VGG_badlands_1_5.csv
# neurons_idx_used_for_similarity_VGG_badlands_2.csv
# neurons_idx_used_for_similarity_VGG_badlands_2_5.csv
# neurons_idx_used_for_similarity_VGG_bridge_1.csv
# neurons_idx_used_for_similarity_VGG_bridge_1_5.csv
# neurons_idx_used_for_similarity_VGG_bridge_2.csv
# neurons_idx_used_for_similarity_VGG_bridge_2_5.csv
# neurons_idx_used_for_similarity_VGG_golf_course_1.csv
# neurons_idx_used_for_similarity_VGG_golf_course_1_5.csv
# neurons_idx_used_for_similarity_VGG_golf_course_2.csv
# neurons_idx_used_for_similarity_VGG_golf_course_2_5.csv
# neurons_idx_used_for_similarity_VGG_highway_1.csv
# neurons_idx_used_for_similarity_VGG_highway_1_5.csv
# neurons_idx_used_for_similarity_VGG_highway_2.csv
# neurons_idx_used_for_similarity_VGG_highway_2_5.csv
# neurons_idx_used_for_similarity_VGG_mountain_1.csv
# neurons_idx_used_for_similarity_VGG_mountain_1_5.csv
# neurons_idx_used_for_similarity_VGG_mountain_2.csv
# neurons_idx_used_for_similarity_VGG_mountain_2_5.csv
# neurons_idx_used_for_similarity_VGG_playground_1.csv
# neurons_idx_used_for_similarity_VGG_playground_1_5.csv
# neurons_idx_used_for_similarity_VGG_playground_2.csv
# neurons_idx_used_for_similarity_VGG_playground_2_5.csv
# original_dataset/
# playground_epsilon_0.05.csv
# playground_epsilon_0.1.csv
# rating data/Animate_Semantic_Ratings.csv
# rating data/Animate_Visual_Ratings.csv
# rating data/Inanimate_Semantic_Ratings.csv
# rating data/Inanimate_Visual_Ratings.csv
# rating data/Indoor_Semantic_Ratings.csv
# rating data/Indoor_Visual_Ratings.csv
# rating data/Outdoor_Semantic_Ratings.csv
# rating data/Outdoor_Visual_Ratings.csv
# rating data/Overall_Ratings.xlsx
# raw data_features_VGG/badlands/badlands_0.pkl
# raw data_features_VGG/badlands/badlands_1.pkl
# raw data_features_VGG/badlands/badlands_10.pkl
# raw data_features_VGG/badlands/badlands_100.pkl
# raw data_features_VGG/badlands/badlands_101.pkl
# raw data_features_VGG/badlands/badlands_102.pkl
# raw data_features_VGG/badlands/badlands_103.pkl
# raw data_features_VGG/badlands/badlands_104.pkl
# raw data_features_VGG/badlands/badlands_105.pkl
# raw data_features_VGG/badlands/badlands_106.pkl
# raw data_features_VGG/badlands/badlands_107.pkl
# raw data_features_VGG/badlands/badlands_108.pkl
# raw data_features_VGG/badlands/badlands_109.pkl
# raw data_features_VGG/badlands/badlands_11.pkl
# raw data_features_VGG/badlands/badlands_110.pkl
# raw data_features_VGG/badlands/badlands_111.pkl
# raw data_features_VGG/badlands/badlands_112.pkl
# raw data_features_VGG/badlands/badlands_113.pkl
# raw data_features_VGG/badlands/badlands_114.pkl
# raw data_features_VGG/badlands/badlands_115.pkl
# raw data_features_VGG/badlands/badlands_116.pkl
# raw data_features_VGG/badlands/badlands_117.pkl
# raw data_features_VGG/badlands/badlands_118.pkl
# raw data_features_VGG/badlands/badlands_119.pkl
# raw data_features_VGG/badlands/badlands_12.pkl
# raw data_features_VGG/badlands/badlands_120.pkl
# raw data_features_VGG/badlands/badlands_121.pkl
# raw data_features_VGG/badlands/badlands_122.pkl
# raw data_features_VGG/badlands/badlands_123.pkl
# raw data_features_VGG/badlands/badlands_124.pkl
# raw data_features_VGG/badlands/badlands_125.pkl
# raw data_features_VGG/badlands/badlands_126.pkl
# raw data_features_VGG/badlands/badlands_127.pkl
# raw data_features_VGG/badlands/badlands_128.pkl
# raw data_features_VGG/badlands/badlands_129.pkl
# raw data_features_VGG/badlands/badlands_13.pkl
# raw data_features_VGG/badlands/badlands_130.pkl
# raw data_features_VGG/badlands/badlands_131.pkl
# raw data_features_VGG/badlands/badlands_132.pkl
# raw data_features_VGG/badlands/badlands_133.pkl
# raw data_features_VGG/badlands/badlands_134.pkl
# raw data_features_VGG/badlands/badlands_135.pkl
# raw data_features_VGG/badlands/badlands_136.pkl
# raw data_features_VGG/badlands/badlands_137.pkl
# raw data_features_VGG/badlands/badlands_138.pkl
# raw data_features_VGG/badlands/badlands_139.pkl
# raw data_features_VGG/badlands/badlands_14.pkl
# raw data_features_VGG/badlands/badlands_140.pkl
# raw data_features_VGG/badlands/badlands_141.pkl
# raw data_features_VGG/badlands/badlands_142.pkl
# raw data_features_VGG/badlands/badlands_143.pkl
# raw data_features_VGG/badlands/badlands_144.pkl
# raw data_features_VGG/badlands/badlands_145.pkl
# raw data_features_VGG/badlands/badlands_146.pkl
# raw data_features_VGG/badlands/badlands_147.pkl
# raw data_features_VGG/badlands/badlands_148.pkl
# raw data_features_VGG/badlands/badlands_149.pkl
# raw data_features_VGG/badlands/badlands_15.pkl
# raw data_features_VGG/badlands/badlands_150.pkl
# raw data_features_VGG/badlands/badlands_151.pkl
# raw data_features_VGG/badlands/badlands_152.pkl
# raw data_features_VGG/badlands/badlands_153.pkl
# raw data_features_VGG/badlands/badlands_154.pkl
# raw data_features_VGG/badlands/badlands_155.pkl
# raw data_features_VGG/badlands/badlands_156.pkl
# raw data_features_VGG/badlands/badlands_157.pkl
# raw data_features_VGG/badlands/badlands_158.pkl
# raw data_features_VGG/badlands/badlands_159.pkl
# raw data_features_VGG/badlands/badlands_16.pkl
# raw data_features_VGG/badlands/badlands_160.pkl
# raw data_features_VGG/badlands/badlands_161.pkl
# raw data_features_VGG/badlands/badlands_162.pkl
# raw data_features_VGG/badlands/badlands_163.pkl
# raw data_features_VGG/badlands/badlands_164.pkl
# raw data_features_VGG/badlands/badlands_165.pkl
# raw data_features_VGG/badlands/badlands_166.pkl
# raw data_features_VGG/badlands/badlands_167.pkl
# raw data_features_VGG/badlands/badlands_168.pkl
# raw data_features_VGG/badlands/badlands_169.pkl
# raw data_features_VGG/badlands/badlands_17.pkl
# raw data_features_VGG/badlands/badlands_170.pkl
# raw data_features_VGG/badlands/badlands_171.pkl
# raw data_features_VGG/badlands/badlands_172.pkl
# raw data_features_VGG/badlands/badlands_173.pkl
# raw data_features_VGG/badlands/badlands_174.pkl
# raw data_features_VGG/badlands/badlands_175.pkl
# raw data_features_VGG/badlands/badlands_176.pkl
# raw data_features_VGG/badlands/badlands_177.pkl
# raw data_features_VGG/badlands/badlands_178.pkl
# raw data_features_VGG/badlands/badlands_179.pkl
# raw data_features_VGG/badlands/badlands_18.pkl
# raw data_features_VGG/badlands/badlands_180.pkl
# raw data_features_VGG/badlands/badlands_181.pkl
# raw data_features_VGG/badlands/badlands_182.pkl
# raw data_features_VGG/badlands/badlands_183.pkl
# raw data_features_VGG/badlands/badlands_184.pkl
# raw data_features_VGG/badlands/badlands_185.pkl
# raw data_features_VGG/badlands/badlands_186.pkl
# raw data_features_VGG/badlands/badlands_187.pkl
# raw data_features_VGG/badlands/badlands_188.pkl
# raw data_features_VGG/badlands/badlands_189.pkl
# raw data_features_VGG/badlands/badlands_19.pkl
# raw data_features_VGG/badlands/badlands_190.pkl
# raw data_features_VGG/badlands/badlands_191.pkl
# raw data_features_VGG/badlands/badlands_192.pkl
# raw data_features_VGG/badlands/badlands_193.pkl
# raw data_features_VGG/badlands/badlands_194.pkl
# raw data_features_VGG/badlands/badlands_195.pkl
# raw data_features_VGG/badlands/badlands_196.pkl
# raw data_features_VGG/badlands/badlands_197.pkl
# raw data_features_VGG/badlands/badlands_198.pkl
# raw data_features_VGG/badlands/badlands_199.pkl
# raw data_features_VGG/badlands/badlands_2.pkl
# raw data_features_VGG/badlands/badlands_20.pkl
# raw data_features_VGG/badlands/badlands_200.pkl
# raw data_features_VGG/badlands/badlands_201.pkl
# raw data_features_VGG/badlands/badlands_202.pkl
# raw data_features_VGG/badlands/badlands_203.pkl
# raw data_features_VGG/badlands/badlands_204.pkl
# raw data_features_VGG/badlands/badlands_205.pkl
# raw data_features_VGG/badlands/badlands_206.pkl
# raw data_features_VGG/badlands/badlands_207.pkl
# raw data_features_VGG/badlands/badlands_208.pkl
# raw data_features_VGG/badlands/badlands_209.pkl
# raw data_features_VGG/badlands/badlands_21.pkl
# raw data_features_VGG/badlands/badlands_210.pkl
# raw data_features_VGG/badlands/badlands_211.pkl
# raw data_features_VGG/badlands/badlands_212.pkl
# raw data_features_VGG/badlands/badlands_213.pkl
# raw data_features_VGG/badlands/badlands_214.pkl
# raw data_features_VGG/badlands/badlands_215.pkl
# raw data_features_VGG/badlands/badlands_216.pkl
# raw data_features_VGG/badlands/badlands_217.pkl
# raw data_features_VGG/badlands/badlands_218.pkl
# raw data_features_VGG/badlands/badlands_219.pkl
# raw data_features_VGG/badlands/badlands_22.pkl
# raw data_features_VGG/badlands/badlands_220.pkl
# raw data_features_VGG/badlands/badlands_221.pkl
# raw data_features_VGG/badlands/badlands_222.pkl
# raw data_features_VGG/badlands/badlands_223.pkl
# raw data_features_VGG/badlands/badlands_224.pkl
# raw data_features_VGG/badlands/badlands_225.pkl
# raw data_features_VGG/badlands/badlands_226.pkl
# raw data_features_VGG/badlands/badlands_227.pkl
# raw data_features_VGG/badlands/badlands_228.pkl
# raw data_features_VGG/badlands/badlands_229.pkl
# raw data_features_VGG/badlands/badlands_23.pkl
# raw data_features_VGG/badlands/badlands_230.pkl
# raw data_features_VGG/badlands/badlands_231.pkl
# raw data_features_VGG/badlands/badlands_24.pkl
# raw data_features_VGG/badlands/badlands_25.pkl
# raw data_features_VGG/badlands/badlands_26.pkl
# raw data_features_VGG/badlands/badlands_27.pkl
# raw data_features_VGG/badlands/badlands_28.pkl
# raw data_features_VGG/badlands/badlands_29.pkl
# raw data_features_VGG/badlands/badlands_3.pkl
# raw data_features_VGG/badlands/badlands_30.pkl
# raw data_features_VGG/badlands/badlands_31.pkl
# raw data_features_VGG/badlands/badlands_32.pkl
# raw data_features_VGG/badlands/badlands_33.pkl
# raw data_features_VGG/badlands/badlands_34.pkl
# raw data_features_VGG/badlands/badlands_35.pkl
# raw data_features_VGG/badlands/badlands_36.pkl
# raw data_features_VGG/badlands/badlands_37.pkl
# raw data_features_VGG/badlands/badlands_38.pkl
# raw data_features_VGG/badlands/badlands_39.pkl
# raw data_features_VGG/badlands/badlands_4.pkl
# raw data_features_VGG/badlands/badlands_40.pkl
# raw data_features_VGG/badlands/badlands_41.pkl
# raw data_features_VGG/badlands/badlands_42.pkl
# raw data_features_VGG/badlands/badlands_43.pkl
# raw data_features_VGG/badlands/badlands_44.pkl
# raw data_features_VGG/badlands/badlands_45.pkl
# raw data_features_VGG/badlands/badlands_46.pkl
# raw data_features_VGG/badlands/badlands_47.pkl
# raw data_features_VGG/badlands/badlands_48.pkl
# raw data_features_VGG/badlands/badlands_49.pkl
# raw data_features_VGG/badlands/badlands_5.pkl
# raw data_features_VGG/badlands/badlands_50.pkl
# raw data_features_VGG/badlands/badlands_51.pkl
# raw data_features_VGG/badlands/badlands_52.pkl
# raw data_features_VGG/badlands/badlands_53.pkl
# raw data_features_VGG/badlands/badlands_54.pkl
# raw data_features_VGG/badlands/badlands_55.pkl
# raw data_features_VGG/badlands/badlands_56.pkl
# raw data_features_VGG/badlands/badlands_57.pkl
# raw data_features_VGG/badlands/badlands_58.pkl
# raw data_features_VGG/badlands/badlands_59.pkl
# raw data_features_VGG/badlands/badlands_6.pkl
# raw data_features_VGG/badlands/badlands_60.pkl
# raw data_features_VGG/badlands/badlands_61.pkl
# raw data_features_VGG/badlands/badlands_62.pkl
# raw data_features_VGG/badlands/badlands_63.pkl
# raw data_features_VGG/badlands/badlands_64.pkl
# raw data_features_VGG/badlands/badlands_65.pkl
# raw data_features_VGG/badlands/badlands_66.pkl
# raw data_features_VGG/badlands/badlands_67.pkl
# raw data_features_VGG/badlands/badlands_68.pkl
# raw data_features_VGG/badlands/badlands_69.pkl
# raw data_features_VGG/badlands/badlands_7.pkl
# raw data_features_VGG/badlands/badlands_70.pkl
# raw data_features_VGG/badlands/badlands_71.pkl
# raw data_features_VGG/badlands/badlands_72.pkl
# raw data_features_VGG/badlands/badlands_73.pkl
# raw data_features_VGG/badlands/badlands_74.pkl
# raw data_features_VGG/badlands/badlands_75.pkl
# raw data_features_VGG/badlands/badlands_76.pkl
# raw data_features_VGG/badlands/badlands_77.pkl
# raw data_features_VGG/badlands/badlands_78.pkl
# raw data_features_VGG/badlands/badlands_79.pkl
# raw data_features_VGG/badlands/badlands_8.pkl
# raw data_features_VGG/badlands/badlands_80.pkl
# raw data_features_VGG/badlands/badlands_81.pkl
# raw data_features_VGG/badlands/badlands_82.pkl
# raw data_features_VGG/badlands/badlands_83.pkl
# raw data_features_VGG/badlands/badlands_84.pkl
# raw data_features_VGG/badlands/badlands_85.pkl
# raw data_features_VGG/badlands/badlands_86.pkl
# raw data_features_VGG/badlands/badlands_87.pkl
# raw data_features_VGG/badlands/badlands_88.pkl
# raw data_features_VGG/badlands/badlands_89.pkl
# raw data_features_VGG/badlands/badlands_9.pkl
# raw data_features_VGG/badlands/badlands_90.pkl
# raw data_features_VGG/badlands/badlands_91.pkl
# raw data_features_VGG/badlands/badlands_92.pkl
# raw data_features_VGG/badlands/badlands_93.pkl
# raw data_features_VGG/badlands/badlands_94.pkl
# raw data_features_VGG/badlands/badlands_95.pkl
# raw data_features_VGG/badlands/badlands_96.pkl
# raw data_features_VGG/badlands/badlands_97.pkl
# raw data_features_VGG/badlands/badlands_98.pkl
# raw data_features_VGG/badlands/badlands_99.pkl
# raw data_features_VGG/bridge/bridge_0.pkl
# raw data_features_VGG/bridge/bridge_1.pkl
# raw data_features_VGG/bridge/bridge_10.pkl
# raw data_features_VGG/bridge/bridge_100.pkl
# raw data_features_VGG/bridge/bridge_101.pkl
# raw data_features_VGG/bridge/bridge_102.pkl
# raw data_features_VGG/bridge/bridge_103.pkl
# raw data_features_VGG/bridge/bridge_104.pkl
# raw data_features_VGG/bridge/bridge_105.pkl
# raw data_features_VGG/bridge/bridge_106.pkl
# raw data_features_VGG/bridge/bridge_107.pkl
# raw data_features_VGG/bridge/bridge_108.pkl
# raw data_features_VGG/bridge/bridge_109.pkl
# raw data_features_VGG/bridge/bridge_11.pkl
# raw data_features_VGG/bridge/bridge_110.pkl
# raw data_features_VGG/bridge/bridge_111.pkl
# raw data_features_VGG/bridge/bridge_112.pkl
# raw data_features_VGG/bridge/bridge_113.pkl
# raw data_features_VGG/bridge/bridge_114.pkl
# raw data_features_VGG/bridge/bridge_115.pkl
# raw data_features_VGG/bridge/bridge_116.pkl
# raw data_features_VGG/bridge/bridge_117.pkl
# raw data_features_VGG/bridge/bridge_118.pkl
# raw data_features_VGG/bridge/bridge_119.pkl
# raw data_features_VGG/bridge/bridge_12.pkl
# raw data_features_VGG/bridge/bridge_120.pkl
# raw data_features_VGG/bridge/bridge_121.pkl
# raw data_features_VGG/bridge/bridge_122.pkl
# raw data_features_VGG/bridge/bridge_123.pkl
# raw data_features_VGG/bridge/bridge_124.pkl
# raw data_features_VGG/bridge/bridge_125.pkl
# raw data_features_VGG/bridge/bridge_126.pkl
# raw data_features_VGG/bridge/bridge_127.pkl
# raw data_features_VGG/bridge/bridge_128.pkl
# raw data_features_VGG/bridge/bridge_129.pkl
# raw data_features_VGG/bridge/bridge_13.pkl
# raw data_features_VGG/bridge/bridge_130.pkl
# raw data_features_VGG/bridge/bridge_131.pkl
# raw data_features_VGG/bridge/bridge_132.pkl
# raw data_features_VGG/bridge/bridge_133.pkl
# raw data_features_VGG/bridge/bridge_134.pkl
# raw data_features_VGG/bridge/bridge_135.pkl
# raw data_features_VGG/bridge/bridge_136.pkl
# raw data_features_VGG/bridge/bridge_137.pkl
# raw data_features_VGG/bridge/bridge_138.pkl
# raw data_features_VGG/bridge/bridge_139.pkl
# raw data_features_VGG/bridge/bridge_14.pkl
# raw data_features_VGG/bridge/bridge_140.pkl
# raw data_features_VGG/bridge/bridge_141.pkl
# raw data_features_VGG/bridge/bridge_142.pkl
# raw data_features_VGG/bridge/bridge_143.pkl
# raw data_features_VGG/bridge/bridge_144.pkl
# raw data_features_VGG/bridge/bridge_145.pkl
# raw data_features_VGG/bridge/bridge_146.pkl
# raw data_features_VGG/bridge/bridge_147.pkl
# raw data_features_VGG/bridge/bridge_148.pkl
# raw data_features_VGG/bridge/bridge_149.pkl
# raw data_features_VGG/bridge/bridge_15.pkl
# raw data_features_VGG/bridge/bridge_150.pkl
# raw data_features_VGG/bridge/bridge_151.pkl
# raw data_features_VGG/bridge/bridge_152.pkl
# raw data_features_VGG/bridge/bridge_153.pkl
# raw data_features_VGG/bridge/bridge_154.pkl
# raw data_features_VGG/bridge/bridge_155.pkl
# raw data_features_VGG/bridge/bridge_156.pkl
# raw data_features_VGG/bridge/bridge_157.pkl
# raw data_features_VGG/bridge/bridge_158.pkl
# raw data_features_VGG/bridge/bridge_159.pkl
# raw data_features_VGG/bridge/bridge_16.pkl
# raw data_features_VGG/bridge/bridge_160.pkl
# raw data_features_VGG/bridge/bridge_161.pkl
# raw data_features_VGG/bridge/bridge_162.pkl
# raw data_features_VGG/bridge/bridge_163.pkl
# raw data_features_VGG/bridge/bridge_164.pkl
# raw data_features_VGG/bridge/bridge_165.pkl
# raw data_features_VGG/bridge/bridge_166.pkl
# raw data_features_VGG/bridge/bridge_167.pkl
# raw data_features_VGG/bridge/bridge_168.pkl
# raw data_features_VGG/bridge/bridge_169.pkl
# raw data_features_VGG/bridge/bridge_17.pkl
# raw data_features_VGG/bridge/bridge_170.pkl
# raw data_features_VGG/bridge/bridge_171.pkl
# raw data_features_VGG/bridge/bridge_172.pkl
# raw data_features_VGG/bridge/bridge_173.pkl
# raw data_features_VGG/bridge/bridge_174.pkl
# raw data_features_VGG/bridge/bridge_175.pkl
# raw data_features_VGG/bridge/bridge_176.pkl
# raw data_features_VGG/bridge/bridge_177.pkl
# raw data_features_VGG/bridge/bridge_178.pkl
# raw data_features_VGG/bridge/bridge_179.pkl
# raw data_features_VGG/bridge/bridge_18.pkl
# raw data_features_VGG/bridge/bridge_180.pkl
# raw data_features_VGG/bridge/bridge_181.pkl
# raw data_features_VGG/bridge/bridge_182.pkl
# raw data_features_VGG/bridge/bridge_183.pkl
# raw data_features_VGG/bridge/bridge_184.pkl
# raw data_features_VGG/bridge/bridge_185.pkl
# raw data_features_VGG/bridge/bridge_186.pkl
# raw data_features_VGG/bridge/bridge_187.pkl
# raw data_features_VGG/bridge/bridge_188.pkl
# raw data_features_VGG/bridge/bridge_189.pkl
# raw data_features_VGG/bridge/bridge_19.pkl
# raw data_features_VGG/bridge/bridge_190.pkl
# raw data_features_VGG/bridge/bridge_191.pkl
# raw data_features_VGG/bridge/bridge_192.pkl
# raw data_features_VGG/bridge/bridge_193.pkl
# raw data_features_VGG/bridge/bridge_194.pkl
# raw data_features_VGG/bridge/bridge_195.pkl
# raw data_features_VGG/bridge/bridge_196.pkl
# raw data_features_VGG/bridge/bridge_197.pkl
# raw data_features_VGG/bridge/bridge_198.pkl
# raw data_features_VGG/bridge/bridge_199.pkl
# raw data_features_VGG/bridge/bridge_2.pkl
# raw data_features_VGG/bridge/bridge_20.pkl
# raw data_features_VGG/bridge/bridge_200.pkl
# raw data_features_VGG/bridge/bridge_201.pkl
# raw data_features_VGG/bridge/bridge_202.pkl
# raw data_features_VGG/bridge/bridge_203.pkl
# raw data_features_VGG/bridge/bridge_204.pkl
# raw data_features_VGG/bridge/bridge_205.pkl
# raw data_features_VGG/bridge/bridge_206.pkl
# raw data_features_VGG/bridge/bridge_207.pkl
# raw data_features_VGG/bridge/bridge_208.pkl
# raw data_features_VGG/bridge/bridge_209.pkl
# raw data_features_VGG/bridge/bridge_21.pkl
# raw data_features_VGG/bridge/bridge_210.pkl
# raw data_features_VGG/bridge/bridge_211.pkl
# raw data_features_VGG/bridge/bridge_212.pkl
# raw data_features_VGG/bridge/bridge_213.pkl
# raw data_features_VGG/bridge/bridge_214.pkl
# raw data_features_VGG/bridge/bridge_215.pkl
# raw data_features_VGG/bridge/bridge_216.pkl
# raw data_features_VGG/bridge/bridge_217.pkl
# raw data_features_VGG/bridge/bridge_218.pkl
# raw data_features_VGG/bridge/bridge_219.pkl
# raw data_features_VGG/bridge/bridge_22.pkl
# raw data_features_VGG/bridge/bridge_220.pkl
# raw data_features_VGG/bridge/bridge_221.pkl
# raw data_features_VGG/bridge/bridge_222.pkl
# raw data_features_VGG/bridge/bridge_223.pkl
# raw data_features_VGG/bridge/bridge_224.pkl
# raw data_features_VGG/bridge/bridge_225.pkl
# raw data_features_VGG/bridge/bridge_226.pkl
# raw data_features_VGG/bridge/bridge_227.pkl
# raw data_features_VGG/bridge/bridge_228.pkl
# raw data_features_VGG/bridge/bridge_229.pkl
# raw data_features_VGG/bridge/bridge_23.pkl
# raw data_features_VGG/bridge/bridge_230.pkl
# raw data_features_VGG/bridge/bridge_231.pkl
# raw data_features_VGG/bridge/bridge_232.pkl
# raw data_features_VGG/bridge/bridge_233.pkl
# raw data_features_VGG/bridge/bridge_234.pkl
# raw data_features_VGG/bridge/bridge_235.pkl
# raw data_features_VGG/bridge/bridge_236.pkl
# raw data_features_VGG/bridge/bridge_237.pkl
# raw data_features_VGG/bridge/bridge_238.pkl
# raw data_features_VGG/bridge/bridge_239.pkl
# raw data_features_VGG/bridge/bridge_24.pkl
# raw data_features_VGG/bridge/bridge_240.pkl
# raw data_features_VGG/bridge/bridge_241.pkl
# raw data_features_VGG/bridge/bridge_242.pkl
# raw data_features_VGG/bridge/bridge_243.pkl
# raw data_features_VGG/bridge/bridge_244.pkl
# raw data_features_VGG/bridge/bridge_245.pkl
# raw data_features_VGG/bridge/bridge_246.pkl
# raw data_features_VGG/bridge/bridge_247.pkl
# raw data_features_VGG/bridge/bridge_248.pkl
# raw data_features_VGG/bridge/bridge_249.pkl
# raw data_features_VGG/bridge/bridge_25.pkl
# raw data_features_VGG/bridge/bridge_250.pkl
# raw data_features_VGG/bridge/bridge_251.pkl
# raw data_features_VGG/bridge/bridge_252.pkl
# raw data_features_VGG/bridge/bridge_253.pkl
# raw data_features_VGG/bridge/bridge_254.pkl
# raw data_features_VGG/bridge/bridge_255.pkl
# raw data_features_VGG/bridge/bridge_256.pkl
# raw data_features_VGG/bridge/bridge_257.pkl
# raw data_features_VGG/bridge/bridge_258.pkl
# raw data_features_VGG/bridge/bridge_259.pkl
# raw data_features_VGG/bridge/bridge_26.pkl
# raw data_features_VGG/bridge/bridge_260.pkl
# raw data_features_VGG/bridge/bridge_261.pkl
# raw data_features_VGG/bridge/bridge_262.pkl
# raw data_features_VGG/bridge/bridge_263.pkl
# raw data_features_VGG/bridge/bridge_264.pkl
# raw data_features_VGG/bridge/bridge_265.pkl
# raw data_features_VGG/bridge/bridge_266.pkl
# raw data_features_VGG/bridge/bridge_27.pkl
# raw data_features_VGG/bridge/bridge_28.pkl
# raw data_features_VGG/bridge/bridge_29.pkl
# raw data_features_VGG/bridge/bridge_3.pkl
# raw data_features_VGG/bridge/bridge_30.pkl
# raw data_features_VGG/bridge/bridge_31.pkl
# raw data_features_VGG/bridge/bridge_32.pkl
# raw data_features_VGG/bridge/bridge_33.pkl
# raw data_features_VGG/bridge/bridge_34.pkl
# raw data_features_VGG/bridge/bridge_35.pkl
# raw data_features_VGG/bridge/bridge_36.pkl
# raw data_features_VGG/bridge/bridge_37.pkl
# raw data_features_VGG/bridge/bridge_38.pkl
# raw data_features_VGG/bridge/bridge_39.pkl
# raw data_features_VGG/bridge/bridge_4.pkl
# raw data_features_VGG/bridge/bridge_40.pkl
# raw data_features_VGG/bridge/bridge_41.pkl
# raw data_features_VGG/bridge/bridge_42.pkl
# raw data_features_VGG/bridge/bridge_43.pkl
# raw data_features_VGG/bridge/bridge_44.pkl
# raw data_features_VGG/bridge/bridge_45.pkl
# raw data_features_VGG/bridge/bridge_46.pkl
# raw data_features_VGG/bridge/bridge_47.pkl
# raw data_features_VGG/bridge/bridge_48.pkl
# raw data_features_VGG/bridge/bridge_49.pkl
# raw data_features_VGG/bridge/bridge_5.pkl
# raw data_features_VGG/bridge/bridge_50.pkl
# raw data_features_VGG/bridge/bridge_51.pkl
# raw data_features_VGG/bridge/bridge_52.pkl
# raw data_features_VGG/bridge/bridge_53.pkl
# raw data_features_VGG/bridge/bridge_54.pkl
# raw data_features_VGG/bridge/bridge_55.pkl
# raw data_features_VGG/bridge/bridge_56.pkl
# raw data_features_VGG/bridge/bridge_57.pkl
# raw data_features_VGG/bridge/bridge_58.pkl
# raw data_features_VGG/bridge/bridge_59.pkl
# raw data_features_VGG/bridge/bridge_6.pkl
# raw data_features_VGG/bridge/bridge_60.pkl
# raw data_features_VGG/bridge/bridge_61.pkl
# raw data_features_VGG/bridge/bridge_62.pkl
# raw data_features_VGG/bridge/bridge_63.pkl
# raw data_features_VGG/bridge/bridge_64.pkl
# raw data_features_VGG/bridge/bridge_65.pkl
# raw data_features_VGG/bridge/bridge_66.pkl
# raw data_features_VGG/bridge/bridge_67.pkl
# raw data_features_VGG/bridge/bridge_68.pkl
# raw data_features_VGG/bridge/bridge_69.pkl
# raw data_features_VGG/bridge/bridge_7.pkl
# raw data_features_VGG/bridge/bridge_70.pkl
# raw data_features_VGG/bridge/bridge_71.pkl
# raw data_features_VGG/bridge/bridge_72.pkl
# raw data_features_VGG/bridge/bridge_73.pkl
# raw data_features_VGG/bridge/bridge_74.pkl
# raw data_features_VGG/bridge/bridge_75.pkl
# raw data_features_VGG/bridge/bridge_76.pkl
# raw data_features_VGG/bridge/bridge_77.pkl
# raw data_features_VGG/bridge/bridge_78.pkl
# raw data_features_VGG/bridge/bridge_79.pkl
# raw data_features_VGG/bridge/bridge_8.pkl
# raw data_features_VGG/bridge/bridge_80.pkl
# raw data_features_VGG/bridge/bridge_81.pkl
# raw data_features_VGG/bridge/bridge_82.pkl
# raw data_features_VGG/bridge/bridge_83.pkl
# raw data_features_VGG/bridge/bridge_84.pkl
# raw data_features_VGG/bridge/bridge_85.pkl
# raw data_features_VGG/bridge/bridge_86.pkl
# raw data_features_VGG/bridge/bridge_87.pkl
# raw data_features_VGG/bridge/bridge_88.pkl
# raw data_features_VGG/bridge/bridge_89.pkl
# raw data_features_VGG/bridge/bridge_9.pkl
# raw data_features_VGG/bridge/bridge_90.pkl
# raw data_features_VGG/bridge/bridge_91.pkl
# raw data_features_VGG/bridge/bridge_92.pkl
# raw data_features_VGG/bridge/bridge_93.pkl
# raw data_features_VGG/bridge/bridge_94.pkl
# raw data_features_VGG/bridge/bridge_95.pkl
# raw data_features_VGG/bridge/bridge_96.pkl
# raw data_features_VGG/bridge/bridge_97.pkl
# raw data_features_VGG/bridge/bridge_98.pkl
# raw data_features_VGG/bridge/bridge_99.pkl
# raw data_features_VGG/golf_course/golf_course_0.pkl
# raw data_features_VGG/golf_course/golf_course_1.pkl
# raw data_features_VGG/golf_course/golf_course_10.pkl
# raw data_features_VGG/golf_course/golf_course_100.pkl
# raw data_features_VGG/golf_course/golf_course_101.pkl
# raw data_features_VGG/golf_course/golf_course_102.pkl
# raw data_features_VGG/golf_course/golf_course_103.pkl
# raw data_features_VGG/golf_course/golf_course_104.pkl
# raw data_features_VGG/golf_course/golf_course_105.pkl
# raw data_features_VGG/golf_course/golf_course_106.pkl
# raw data_features_VGG/golf_course/golf_course_107.pkl
# raw data_features_VGG/golf_course/golf_course_108.pkl
# raw data_features_VGG/golf_course/golf_course_109.pkl
# raw data_features_VGG/golf_course/golf_course_11.pkl
# raw data_features_VGG/golf_course/golf_course_110.pkl
# raw data_features_VGG/golf_course/golf_course_111.pkl
# raw data_features_VGG/golf_course/golf_course_112.pkl
# raw data_features_VGG/golf_course/golf_course_113.pkl
# raw data_features_VGG/golf_course/golf_course_114.pkl
# raw data_features_VGG/golf_course/golf_course_115.pkl
# raw data_features_VGG/golf_course/golf_course_116.pkl
# raw data_features_VGG/golf_course/golf_course_117.pkl
# raw data_features_VGG/golf_course/golf_course_118.pkl
# raw data_features_VGG/golf_course/golf_course_119.pkl
# raw data_features_VGG/golf_course/golf_course_12.pkl
# raw data_features_VGG/golf_course/golf_course_120.pkl
# raw data_features_VGG/golf_course/golf_course_121.pkl
# raw data_features_VGG/golf_course/golf_course_122.pkl
# raw data_features_VGG/golf_course/golf_course_123.pkl
# raw data_features_VGG/golf_course/golf_course_124.pkl
# raw data_features_VGG/golf_course/golf_course_125.pkl
# raw data_features_VGG/golf_course/golf_course_126.pkl
# raw data_features_VGG/golf_course/golf_course_127.pkl
# raw data_features_VGG/golf_course/golf_course_128.pkl
# raw data_features_VGG/golf_course/golf_course_129.pkl
# raw data_features_VGG/golf_course/golf_course_13.pkl
# raw data_features_VGG/golf_course/golf_course_130.pkl
# raw data_features_VGG/golf_course/golf_course_131.pkl
# raw data_features_VGG/golf_course/golf_course_132.pkl
# raw data_features_VGG/golf_course/golf_course_133.pkl
# raw data_features_VGG/golf_course/golf_course_134.pkl
# raw data_features_VGG/golf_course/golf_course_135.pkl
# raw data_features_VGG/golf_course/golf_course_136.pkl
# ...
# raw data_features_VGG_multicat/golf_course_3.pkl
# raw data_features_VGG_multicat/golf_course_30.pkl
# raw data_features_VGG_multicat/golf_course_31.pkl
# raw data_features_VGG_multicat/golf_course_32.pkl
# raw data_features_VGG_multicat/golf_course_33.pkl
# raw data_features_VGG_multicat/golf_course_34.pkl
# raw data_features_VGG_multicat/golf_course_35.pkl
# raw data_features_VGG_multicat/golf_course_36.pkl
# raw data_features_VGG_multicat/golf_course_37.pkl
# raw data_features_VGG_multicat/golf_course_38.pkl
# raw data_features_VGG_multicat/golf_course_39.pkl
# raw data_features_VGG_multicat/golf_course_4.pkl
# raw data_features_VGG_multicat/golf_course_40.pkl
# raw data_features_VGG_multicat/golf_course_41.pkl
# raw data_features_VGG_multicat/golf_course_42.pkl
# raw data_features_VGG_multicat/golf_course_43.pkl
# raw data_features_VGG_multicat/golf_course_44.pkl
# raw data_features_VGG_multicat/golf_course_45.pkl
# raw data_features_VGG_multicat/golf_course_46.pkl
# raw data_features_VGG_multicat/golf_course_47.pkl
# raw data_features_VGG_multicat/golf_course_48.pkl
# raw data_features_VGG_multicat/golf_course_49.pkl
# raw data_features_VGG_multicat/golf_course_5.pkl
# raw data_features_VGG_multicat/golf_course_6.pkl
# raw data_features_VGG_multicat/golf_course_7.pkl
# raw data_features_VGG_multicat/golf_course_8.pkl
# raw data_features_VGG_multicat/golf_course_9.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_0.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_1.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_10.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_11.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_12.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_13.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_14.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_15.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_16.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_17.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_18.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_19.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_2.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_20.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_21.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_22.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_23.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_24.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_25.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_26.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_27.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_28.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_29.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_3.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_30.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_31.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_32.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_33.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_34.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_35.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_36.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_37.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_38.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_39.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_4.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_40.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_41.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_42.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_43.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_44.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_45.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_46.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_47.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_48.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_49.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_5.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_50.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_51.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_52.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_53.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_54.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_55.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_56.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_57.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_58.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_59.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_6.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_7.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_8.pkl
# raw data_features_VGG_new_dataset/Indoor_Scene/Indoor_Scene_9.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_0.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_1.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_10.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_11.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_12.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_13.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_14.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_15.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_16.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_17.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_18.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_19.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_2.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_20.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_21.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_22.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_23.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_24.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_25.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_26.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_27.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_28.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_29.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_3.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_30.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_31.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_32.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_33.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_34.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_35.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_36.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_37.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_38.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_39.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_4.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_40.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_41.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_42.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_43.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_44.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_45.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_46.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_47.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_48.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_49.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_5.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_50.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_51.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_52.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_53.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_54.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_55.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_56.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_57.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_58.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_59.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_6.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_7.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_8.pkl
# raw data_features_VGG_new_dataset/Outdoor_Scene/Outdoor_Scene_9.pkl
# results_epsilon_0.05.csv
# results_epsilon_0.1.csv
# similarity_VGG_Indoor_Scene_1.csv
# similarity_VGG_Indoor_Scene_1_5.csv
# similarity_VGG_Indoor_Scene_2.csv
# similarity_VGG_Indoor_Scene_2_5.csv
# similarity_VGG_Outdoor_Scene_1.csv
# similarity_VGG_Outdoor_Scene_1_5.csv
# similarity_VGG_Outdoor_Scene_2.csv
# similarity_VGG_Outdoor_Scene_2_5.csv
# similarity_VGG_badlands_1.csv
# similarity_VGG_badlands_1_5.csv
# similarity_VGG_badlands_2.csv
# similarity_VGG_badlands_2_5.csv
# similarity_VGG_bridge_1.csv
# similarity_VGG_bridge_1_5.csv
# similarity_VGG_bridge_2.csv
# similarity_VGG_bridge_2_5.csv
# similarity_VGG_golf_course_1.csv
# similarity_VGG_golf_course_1_5.csv
# similarity_VGG_golf_course_2.csv
# similarity_VGG_golf_course_2_5.csv
# similarity_VGG_highway_1.csv
# similarity_VGG_highway_1_5.csv
# similarity_VGG_highway_2.csv
# similarity_VGG_highway_2_5.csv
# similarity_VGG_index_Indoor_Scene_1.csv
# similarity_VGG_index_Indoor_Scene_1_5.csv
# similarity_VGG_index_Indoor_Scene_2.csv
# similarity_VGG_index_Indoor_Scene_2_5.csv
# similarity_VGG_index_Outdoor_Scene_1.csv
# similarity_VGG_index_Outdoor_Scene_1_5.csv
# similarity_VGG_index_Outdoor_Scene_2.csv
# similarity_VGG_index_Outdoor_Scene_2_5.csv
# similarity_VGG_mountain_1.csv
# similarity_VGG_mountain_1_5.csv
# similarity_VGG_mountain_2.csv
# similarity_VGG_mountain_2_5.csv
# similarity_VGG_playground_1.csv
# similarity_VGG_playground_1_5.csv
# similarity_VGG_playground_2.csv
# similarity_VGG_playground_2_5.csv
# similarity_VGG_regular_Indoor_Scene_.csv
# similarity_VGG_regular_Outdoor_Scene_.csv
# similarity_VGG_regular_index_Indoor_Scene_.csv
# similarity_VGG_regular_index_Outdoor_Scene_.csv
# similarity_df_regular/
# similarity_df_regular/similarity_between_pairs_VGGbadlands.csv
# similarity_df_regular/similarity_between_pairs_VGGbridge.csv
# similarity_df_regular/similarity_between_pairs_VGGgolf_course.csv
# similarity_df_regular/similarity_between_pairs_VGGhighway.csv
# similarity_df_regular/similarity_between_pairs_VGGmountain.csv
# similarity_df_regular/similarity_between_pairs_VGGplayground.csv
# similarity_topx_VGG_Indoor_Scene_1.csv
# similarity_topx_VGG_Indoor_Scene_1_5.csv
# similarity_topx_VGG_Indoor_Scene_2.csv
# similarity_topx_VGG_Outdoor_Scene_1.csv
# similarity_topx_VGG_Outdoor_Scene_1_5.csv
# similarity_topx_VGG_Outdoor_Scene_2.csv
# similarity_topx_VGG_badlands_1.csv
# similarity_topx_VGG_badlands_1_5.csv
# similarity_topx_VGG_badlands_2.csv
# similarity_topx_VGG_bridge_1.csv
# similarity_topx_VGG_bridge_1_5.csv
# similarity_topx_VGG_bridge_2.csv
# similarity_topx_VGG_golf_course_1.csv
# similarity_topx_VGG_golf_course_1_5.csv
# similarity_topx_VGG_golf_course_2.csv
# similarity_topx_VGG_highway_1.csv
# similarity_topx_VGG_highway_1_5.csv
# similarity_topx_VGG_highway_2.csv
# similarity_topx_VGG_index_Indoor_Scene_1.csv
# similarity_topx_VGG_index_Indoor_Scene_1_5.csv
# similarity_topx_VGG_index_Indoor_Scene_2.csv
# similarity_topx_VGG_index_Outdoor_Scene_1.csv
# similarity_topx_VGG_index_Outdoor_Scene_1_5.csv
# similarity_topx_VGG_index_Outdoor_Scene_2.csv
# similarity_topx_VGG_mountain_1.csv
# similarity_topx_VGG_mountain_1_5.csv
# similarity_topx_VGG_mountain_2.csv
# similarity_topx_VGG_playground_1.csv
# similarity_topx_VGG_playground_1_5.csv
# similarity_topx_VGG_playground_2.csv
# similarity_topx_per_catVGG_badlands_1.csv
# similarity_topx_per_catVGG_badlands_1_5.csv
# similarity_topx_per_catVGG_badlands_2.csv
# similarity_topx_per_catVGG_bridge_1.csv
# similarity_topx_per_catVGG_bridge_1_5.csv
# similarity_topx_per_catVGG_bridge_2.csv
# similarity_topx_per_catVGG_golf_course_1.csv
# similarity_topx_per_catVGG_golf_course_1_5.csv
# similarity_topx_per_catVGG_golf_course_2.csv
# similarity_topx_per_catVGG_highway_1.csv
# similarity_topx_per_catVGG_highway_1_5.csv
# similarity_topx_per_catVGG_highway_2.csv
# similarity_topx_per_catVGG_mountain_1.csv
# similarity_topx_per_catVGG_mountain_1_5.csv
# similarity_topx_per_catVGG_mountain_2.csv
# similarity_topx_per_catVGG_playground_1.csv
# similarity_topx_per_catVGG_playground_1_5.csv
# similarity_topx_per_catVGG_playground_2.csv
# similarity_topx_per_cat_Indoor_Scene_1.csv
# similarity_topx_per_cat_Indoor_Scene_1_5.csv
# similarity_topx_per_cat_Indoor_Scene_2.csv
# similarity_topx_per_cat_Outdoor_Scene_1.csv
# similarity_topx_per_cat_Outdoor_Scene_1_5.csv
# similarity_topx_per_cat_Outdoor_Scene_2.csv
# similarity_topx_per_cat_index_Indoor_Scene_1.csv
# similarity_topx_per_cat_index_Indoor_Scene_1_5.csv
# similarity_topx_per_cat_index_Indoor_Scene_2.csv
# similarity_topx_per_cat_index_Outdoor_Scene_1.csv
# similarity_topx_per_cat_index_Outdoor_Scene_1_5.csv
# similarity_topx_per_cat_index_Outdoor_Scene_2.csv
# similarity_topx_per_cat_percentileVGG_badlands_85.csv
# similarity_topx_per_cat_percentileVGG_badlands_90.csv
# similarity_topx_per_cat_percentileVGG_badlands_95.csv
# similarity_topx_per_cat_percentileVGG_bridge_85.csv
# similarity_topx_per_cat_percentileVGG_bridge_90.csv
# similarity_topx_per_cat_percentileVGG_bridge_95.csv
# similarity_topx_per_cat_percentileVGG_golf_course_85.csv
# similarity_topx_per_cat_percentileVGG_golf_course_90.csv
# similarity_topx_per_cat_percentileVGG_golf_course_95.csv
# similarity_topx_per_cat_percentileVGG_highway_85.csv
# similarity_topx_per_cat_percentileVGG_highway_90.csv
# similarity_topx_per_cat_percentileVGG_highway_95.csv
# similarity_topx_per_cat_percentileVGG_mountain_85.csv
# similarity_topx_per_cat_percentileVGG_mountain_90.csv
# similarity_topx_per_cat_percentileVGG_mountain_95.csv
# similarity_topx_per_cat_percentileVGG_playground_85.csv
# similarity_topx_per_cat_percentileVGG_playground_90.csv
# similarity_topx_per_cat_percentileVGG_playground_95.csv
# similarity_topx_per_cat_percentile_VGG_Indoor_Scene_85.csv
# similarity_topx_per_cat_percentile_VGG_Indoor_Scene_90.csv
# similarity_topx_per_cat_percentile_VGG_Indoor_Scene_95.csv
# similarity_topx_per_cat_percentile_VGG_Outdoor_Scene_85.csv
# similarity_topx_per_cat_percentile_VGG_Outdoor_Scene_90.csv
# similarity_topx_per_cat_percentile_VGG_Outdoor_Scene_95.csv
# similarity_topx_per_cat_percentile_VGG_index_Indoor_Scene_85.csv
# similarity_topx_per_cat_percentile_VGG_index_Indoor_Scene_90.csv
# similarity_topx_per_cat_percentile_VGG_index_Indoor_Scene_95.csv
# similarity_topx_per_cat_percentile_VGG_index_Outdoor_Scene_85.csv
# similarity_topx_per_cat_percentile_VGG_index_Outdoor_Scene_90.csv
# similarity_topx_per_cat_percentile_VGG_index_Outdoor_Scene_95.csv
# sum_activations.pt
# sum_activations_Indoor_Scene.pt
# sum_activations_Outdoor_Scene.pt
# sum_activations_badlands.pt
# sum_activations_bridge.pt
# sum_activations_golf_course.pt
# sum_activations_highway.pt
# sum_activations_mountain.pt
# sum_activations_new_dataset.pt
# sum_activations_playground.pt

# %%
similairy_dfs_paths = ['similarity_df_regular/similarity_between_pairs_VGGbadlands.csv',
'similarity_df_regular/similarity_between_pairs_VGGbridge.csv',
'similarity_df_regular/similarity_between_pairs_VGGgolf_course.csv',
'similarity_df_regular/similarity_between_pairs_VGGhighway.csv',
'similarity_df_regular/similarity_between_pairs_VGGmountain.csv',
'similarity_df_regular/similarity_between_pairs_VGGplayground.csv']

# %%
duplicate_images = ['playground_3.pkl','bridge_219.pkl','highway_106.pkl','highway_109.pkl','highway_119.pkl',
                    'golf_course_24.pkl',
                    'highway_121.pkl','highway_130.pkl','highway_140.pkl','highway_157.pkl','highway_170.pkl',
                    'highway_180.pkl','highway_191.pkl','highway_248.pkl','highway_377.pkl','highway_411.pkl','highway_70.pkl','highway_274.pkl','highway_198.pkl',
                    'mountain_119.pkl','mountain_172.pkl','mountain_121.pkl','mountain_45.pkl','mountain_74.pkl','mountain_91.pkl','mountain_194.pkl','mountain_87.pkl','mountain_305.pkl']

# %%
similairy_dfs_paths = ['similarity_df_regular/similarity_between_pairs_VGGgolf_course.csv']

# %%
results = pd.DataFrame([])
all_selected_images_dict = {}

for cat in similairy_dfs_paths:


    category_name = cat.split('VGG')[-1].split('.')[0]
    print(category_name)

    cur_similarity_df = read_csv_from_bucket(bucket=bucket,filename=cat)

    # removing duplicate images:
    bad_images_cat = [img for img in duplicate_images if category_name in img]
    for bad_img in bad_images_cat:

        bad_idx = cur_similarity_df[(cur_similarity_df['image1'] == bad_img) | (cur_similarity_df['image2'] == bad_img)].index
        cur_similarity_df = cur_similarity_df.drop(index=bad_idx)
        

    cur_similarity_df['image1'] = cur_similarity_df['image1'].str.replace('.pkl','.jpg')
    cur_similarity_df['image2'] = cur_similarity_df['image2'].str.replace('.pkl','.jpg')

    cur_similarity_df['mean_network_sim']=cur_similarity_df[[colname for colname in cur_similarity_df.columns if 'level' in colname]].mean(axis=1)
    all_unique_images=(set(cur_similarity_df['image1'].values) | set(cur_similarity_df['image2'].values))
    number_of_images = len(all_unique_images)
    cur_similarity_df['numeric_image1']=cur_similarity_df['image1'].copy()
    cur_similarity_df['numeric_image2']=cur_similarity_df['image2'].copy()

    names_to_numbers_dict={name:i for (name,i) in zip(all_unique_images,range(number_of_images))}
    numbers_to_names_dict={name:key for key,name in names_to_numbers_dict.items()}
    cur_similarity_df['numeric_image1'].replace(names_to_numbers_dict,inplace=True)
    cur_similarity_df['numeric_image2'].replace(names_to_numbers_dict,inplace=True)

    d_matrix_level_dict = {}
    for j,sim_level in enumerate(['level_0','level_6','mean_network_sim']):
        #get from the network: 
        curr_sim_df_for_correlation=cur_similarity_df.copy()
        d_matrix=np.zeros([number_of_images,number_of_images])
        for i in range(len(curr_sim_df_for_correlation)):
            row=curr_sim_df_for_correlation['numeric_image1'].iloc[i]
            col=curr_sim_df_for_correlation['numeric_image2'].iloc[i]
            val=curr_sim_df_for_correlation[sim_level].iloc[i]
            d_matrix[row,col]=1-val
            d_matrix[col,row]=1-val
            d_matrix[row,row]=0

        d_matrix_level_dict[sim_level] = d_matrix
        
    SIM_M = d_matrix_level_dict['level_6'] - d_matrix_level_dict['level_0']
    SIM_Mean = d_matrix_level_dict['mean_network_sim']


    epsilon_size = [0.05]
    # Define the epsilon value
    for epsilon in epsilon_size:
        print(f'Epsilon size {epsilon}')
        start_time = time.time()

        # Set the size of the matrix
        n = SIM_M.shape[0]
        n_images = n
        images_to_select=10

        # Define the problem
        prob = LpProblem("Image Selection", LpMaximize)
        # Define the decision variables
        x = LpVariable.dicts("x", range(n_images), 0, 1, LpBinary)
        y = LpVariable.dicts("y", (range(n_images), range(n_images)), 0, 1, LpBinary)
        z = LpVariable.dicts("z", (range(n_images), range(n_images)), 0, 1, LpBinary)

        # Define the objective function
        prob += lpSum([SIM_M[i][j]*z[i][j]-SIM_M[i][j]*y[i][j] for i in range(n_images) for j in range(n_images)])
        #make sure only "images_to_select" are selected:
        prob += lpSum([x[i] for i in range(n_images)]) == images_to_select
        #make sure that the averages are close up tp epsilon: 
        prob += lpSum([SIM_Mean[i][j]*y[i][j] for i in range(n_images) for j in range(n_images)]) - lpSum([SIM_Mean[i][j]*z[i][j] for i in range(n_images) for j in range(n_images)])<=epsilon
        prob += lpSum([SIM_Mean[i][j]*y[i][j] for i in range(n_images) for j in range(n_images)]) - lpSum([SIM_Mean[i][j]*z[i][j] for i in range(n_images) for j in range(n_images)])>=-epsilon


        for i in range(n_images):
            prob += lpSum([y[j][i] for j in range(n_images)]) == x[i]
            prob += lpSum([z[j][i] for j in range(n_images)]) == x[i]

            prob += (x[i] + lpSum([y[i][j] for j in range(n_images)]) + lpSum([z[i][j] for j in range(n_images)]) )<= 1

            for j in range(n_images):
                if i == j:
                    prob += z[i][j] == 0
                    prob += y[i][j] == 0
                prob += y[j][i] <= x[i]
                prob += z[j][i] <= x[i]


        # Solve the problem
        prob.solve()
        # Print the status of the problem
        print("Status:", LpStatus[prob.status])
        # Print selected targets and D1 and D2 images 
        selected_target_and_distractors_dict ={}
        for i in range(n_images):
            if x[i].value() == 1:
                #print(f"Target {i}:")
                # high level distractor
                y1 = [j for j in range(n_images) if y[j][i].value() == 1]
                # low level distractor
                z2 = [j for j in range(n_images) if z[j][i].value() == 1]
                #print(f" y1: {y1}")
                #print(f" z2: {z2}")
                selected_target_and_distractors_dict[i] = (z2,y1)

        #print('x:\n',[x[j].value() for j in range(n_images)])
        y_vals=np.array([y[i][j].value() for i in range(n_images) for j in range(n_images)]).reshape([n_images,n_images])
        #print('y:\n',y_vals)
        z_vals=np.array([z[i][j].value() for i in range(n_images) for j in range(n_images)]).reshape([n_images,n_images])
        #print('z:\n',z_vals)
        end_time = time.time()

        selected_target_and_distractors_names_dict = {}
        for key , value in selected_target_and_distractors_dict.items():
            
            # Convert the first value in the tuple to a word using the second dictionary
            word1 = numbers_to_names_dict[value[0][0]]
            word1 = word1.replace('.pkl','.jpg')
            # Convert the second value in the tuple to a word using the second dictionary
            word2 = numbers_to_names_dict[value[1][0]]
            word2 = word2.replace('.pkl','.jpg')
            # Look up the word corresponding to the key in the second dictionary
            new_key = numbers_to_names_dict[key]
            new_key = new_key.replace('.pkl','.jpg')
            # Add the new key-value pair to the new dictionary
            selected_target_and_distractors_names_dict[new_key] = word1, word2


        sim_df_selected = pd.DataFrame([])
        for key,values in selected_target_and_distractors_names_dict.items():
            target_sim_df = cur_similarity_df[(cur_similarity_df['image1']== key) | (cur_similarity_df['image2'] == key)]

            dist_0_sim_df = target_sim_df[(target_sim_df['image1']== values[0]) | (target_sim_df['image2'] == values[0])]
            dist_0_sim_df['distractor_level'] = 0
            dist_1_sim_df = target_sim_df[(target_sim_df['image1']== values[1]) | (target_sim_df['image2'] == values[1])]
            dist_1_sim_df['distractor_level'] = 1
            sim_df_selected = pd.concat([sim_df_selected,dist_0_sim_df,dist_1_sim_df])


        elapsed_time = (end_time - start_time)/60
        mean_sim_per_layer = sim_df_selected.groupby('distractor_level')[['level_0','level_1','level_2','level_3','level_4','level_5','level_6']].mean()
        mean_similarity = mean_sim_per_layer.mean(axis=1)
        
        d1 = sim_df_selected[sim_df_selected['distractor_level'] == 0 ]['mean_network_sim']
        d2 = sim_df_selected[sim_df_selected['distractor_level'] == 1 ]['mean_network_sim']

        t_stat, p_value = stats.ttest_rel(d1, d2)
        cur_run_line = pd.DataFrame([{'category name':category_name, 'epsilon':epsilon,'d1 mean': mean_similarity[0],'d2 mean': mean_similarity[1],'elapse time':elapsed_time,'p val':p_value,'t stat':t_stat}])
        results = pd.concat([results,cur_run_line])
        key_name = category_name +'_'+ str(epsilon)
        all_selected_images_dict[key_name] = sim_df_selected
# Out:
# golf_course
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
# Epsilon size 0.05

# %%
cur_similarity_df[cur_similarity_df['mean_network_sim'] > 0.89]

# %%
results

# %%
import seaborn as sns
fig,axes = plt.subplots(2,3,figsize = (12,10))
axes = axes.ravel()
numbers = []
for i in range(1,11):
    numbers.append(i)
    numbers.append(i)


for i,cat in enumerate(all_selected_images_dict.keys()):
    df = all_selected_images_dict[cat]
    df['ID'] = numbers
    sns.pointplot(data=df,x='distractor_level', y='mean_network_sim', hue='ID',ax=axes[i])
    axes[i].set_title(cat)
    axes[i].legend('')

# %%
colors = ['red','blue','green', 'red','orange','purple']
fig,ax = plt.subplots()
for i,cat in enumerate(epsilon_2_cat):
    df = all_selected_images_dict[cat]
    y = df.groupby('distractor_level')[['level_0','level_1','level_2','level_3','level_4','level_5','level_6']].mean()
    
    y_std = df.groupby('distractor_level')[['level_0','level_1','level_2','level_3','level_4','level_5','level_6']].std()
    x = ['level_0','level_1','level_2','level_3','level_4','level_5','level_6']
    ax.plot(x, y, label=cat,color=colors[i])
    ax.fill_between(x, y - y_std, y + y_std,color=colors[i], alpha=0.1)


ax.legend()

# %%
save_df_csv_into_bucket(bucket,results,'results_epsilon_0.05.csv')

# %%
save_df_csv_into_bucket(bucket,all_selected_images_dict,'dict_epsilon_0.1.csv')

# %%
all_selected_images_dict
# Out:
# {'bridge_0.05':                image1          image2   level_0   level_1   level_2   level_3  \
#  8441   bridge_128.jpg   bridge_61.jpg  0.413892  0.302557  0.214883  0.166027
#  8378   bridge_128.jpg  bridge_244.jpg  0.199434  0.201220  0.145456  0.135630
#  20812  bridge_184.jpg  bridge_191.jpg  0.397140  0.350096  0.275850  0.211039
#  22281  bridge_191.jpg   bridge_75.jpg  0.276783  0.247402  0.172541  0.128064
#  24261  bridge_202.jpg   bridge_31.jpg  0.443028  0.366328  0.244194  0.163300
#  24268  bridge_202.jpg   bridge_38.jpg  0.240852  0.220152  0.154202  0.109590
#  20422  bridge_181.jpg   bridge_65.jpg  0.527863  0.387840  0.304280  0.266354
#  34612   bridge_60.jpg   bridge_65.jpg  0.194153  0.205021  0.178971  0.117825
#  31131  bridge_253.jpg   bridge_91.jpg  0.476786  0.389937  0.269220  0.164992
#  35349   bridge_82.jpg   bridge_91.jpg  0.273947  0.238672  0.196548  0.125026
#  2879   bridge_108.jpg  bridge_116.jpg  0.447301  0.349201  0.247630  0.197384
#  2914   bridge_108.jpg  bridge_148.jpg  0.264785  0.215066  0.122133  0.103424
#  12853  bridge_146.jpg   bridge_27.jpg  0.559103  0.448715  0.363493  0.357710
#  6617   bridge_121.jpg  bridge_146.jpg  0.216800  0.215747  0.178252  0.126574
#  31366  bridge_256.jpg   bridge_54.jpg  0.561572  0.322146  0.233084  0.200082
#  25689  bridge_211.jpg  bridge_256.jpg  0.217039  0.240871  0.185847  0.164839
#  9988   bridge_134.jpg  bridge_250.jpg  0.593459  0.350738  0.257582  0.236962
#  24682  bridge_205.jpg  bridge_250.jpg  0.216840  0.227517  0.156661  0.098160
#  17935   bridge_17.jpg  bridge_172.jpg  0.511052  0.333230  0.215984  0.126730
#  16605  bridge_163.jpg  bridge_172.jpg  0.240999  0.294224  0.232784  0.197814
#
#          level_4   level_5   level_6 model category1 category2  \
#  8441   0.137987  0.180487  0.166979   VGG    bridge    bridge
#  8378   0.152772  0.443891  0.616580   VGG    bridge    bridge
#  20812  0.176052  0.267951  0.226752   VGG    bridge    bridge
#  22281  0.183027  0.568781  0.770226   VGG    bridge    bridge
#  24261  0.104394  0.230149  0.240853   VGG    bridge    bridge
#  24268  0.267767  0.595506  0.697118   VGG    bridge    bridge
#  20422  0.208789  0.360933  0.338774   VGG    bridge    bridge
#  34612  0.192465  0.434549  0.592433   VGG    bridge    bridge
#  31131  0.132108  0.228528  0.190940   VGG    bridge    bridge
#  35349  0.137811  0.462531  0.613112   VGG    bridge    bridge
#  2879   0.149400  0.248371  0.211636   VGG    bridge    bridge
#  2914   0.056870  0.398125  0.602363   VGG    bridge    bridge
#  12853  0.301480  0.375995  0.386186   VGG    bridge    bridge
#  6617   0.123920  0.488296  0.593169   VGG    bridge    bridge
#  31366  0.248816  0.322871  0.338306   VGG    bridge    bridge
#  25689  0.207634  0.508636  0.620168   VGG    bridge    bridge
#  9988   0.200300  0.374738  0.366190   VGG    bridge    bridge
#  24682  0.086207  0.464745  0.655718   VGG    bridge    bridge
#  17935  0.054675  0.164255  0.137697   VGG    bridge    bridge
#  16605  0.179835  0.533336  0.719496   VGG    bridge    bridge
#
#         mean_network_sim  numeric_image1  numeric_image2  distractor_level
#  8441           0.226116              37             162                 0
#  8378           0.270712              37             225                 1
#  20812          0.272126             209              45                 0
#  22281          0.335261              45             123                 1
#  24261          0.256035              51             129                 0
#  24268          0.326455              51             111                 1
#  20422          0.342119             164              80                 0
#  34612          0.273631              24              80                 1
#  31131          0.264644             240              96                 0
#  35349          0.292521             189              96                 1
#  2879           0.264418             115              31                 0
#  2914           0.251824             115             223                 1
#  12853          0.398955             178             167                 0
#  6617           0.277537             203             178                 1
#  31366          0.318125             181              93                 0
#  25689          0.306433             235             181                 1
#  9988           0.339996              85             202                 0
#  24682          0.272264             190             202                 1
#  17935          0.220518              29             265                 0
#  16605          0.342641             201             265                 1  }

# %%
save_df_csv_into_bucket(bucket,all_selected_images_dict['highway_0.1'],'highway_epsilon_0.1.csv')

# %%
all_selected_images_dict['mountain_0.05']
